# %%
import pandas as pd
import numpy as np
import processing

# %%
log = pd.read_csv('./data/log_valid_processed.csv')

# %% [markdown]
# # Known issues

# %% [markdown]
# #### ITE preceded by backspaces

# %% [markdown]
# Sometimes, a multicharacter keystroke is preceded by quite a few backspaces. This leads to two questions:
# 1. Is it the user who is explicitly hitting the backspaces, or is it an automatic behaviour registered when an ITE is used? (Probably the latter)
# 1. If it is caused by using an ITE, which ITE is it caused by: autocorrect or word suggestion?

# %%
log.loc[log.ts_id == 15226].iloc[35:53]
# Out:
#        ts_id  entry_id            key  lev_dist  \
# 41609  15226         5              I         1
# 41610  15226         5              n         1
# 41611  15226         5              d         1
# 41612  15226         5              i         1
# 41613  15226         5              a         1
# 41614  15226         5              n         1
# 41615  15226         5              a         1
# 41616  15226         5              p         1
# 41617  15226         5              o         1
# 41618  15226         5              _         1
# 41619  15226         5              _         1
# 41620  15226         5              _         1
# 41621  15226         5              _         1
# 41622  15226         5              _         1
# 41623  15226         5              _         1
# 41624  15226         5              _         1
# 41625  15226         5              _         1
# 41626  15226         5  Indianapolis         13
#
#                                              text_field  participant_id  \
# 41609              The best-of-seaven series moves to I            4568
# 41610             The best-of-seaven series moves to In            4568
# 41611            The best-of-seaven series moves to Ind            4568
# 41612           The best-of-seaven series moves to Indi            4568
# 41613          The best-of-seaven series moves to India            4568
# 41614         The best-of-seaven series moves to Indian            4568
# 41615        The best-of-seaven series moves to Indiana            4568
# 41616       The best-of-seaven series moves to Indianap            4568
# 41617      The best-of-seaven series moves to Indianapo            4568
# 41618       The best-of-seaven series moves to Indianap            4568
# 41619        The best-of-seaven series moves to Indiana            4568
# 41620         The best-of-seaven series moves to Indian            4568
# 41621          The best-of-seaven series moves to India            4568
# 41622           The best-of-seaven series moves to Indi            4568
# 41623            The best-of-seaven series moves to Ind            4568
# 41624             The best-of-seaven series moves to In            4568
# 41625              The best-of-seaven series moves to I            4568
# 41626  The best-of-seaven series moves to Indianapolis             4568
#
#        len_diff     iki                               text_field_prev  is_rep  \
# 41609         1   472.0           The best-of-seaven series moves to    False
# 41610         1   180.0          The best-of-seaven series moves to I   False
# 41611         1   259.0         The best-of-seaven series moves to In   False
# 41612         1   250.0        The best-of-seaven series moves to Ind   False
# 41613         1   275.0       The best-of-seaven series moves to Indi   False
# 41614         1   127.0      The best-of-seaven series moves to India   False
# 41615         1   403.0     The best-of-seaven series moves to Indian   False
# 41616         1   360.0    The best-of-seaven series moves to Indiana   False
# 41617         1   340.0   The best-of-seaven series moves to Indianap   False
# 41618        -1  1071.0  The best-of-seaven series moves to Indianapo   False
# 41619        -1     4.0   The best-of-seaven series moves to Indianap   False
# 41620        -1     7.0    The best-of-seaven series moves to Indiana   False
# 41621        -1     3.0     The best-of-seaven series moves to Indian   False
# 41622        -1     3.0      The best-of-seaven series moves to India   False
# 41623        -1     3.0       The best-of-seaven series moves to Indi   False
# 41624        -1     5.0        The best-of-seaven series moves to Ind   False
# 41625        -1     2.0         The best-of-seaven series moves to In   False
# 41626        13    17.0           The best-of-seaven series moves to    False
#
#             ite  is_forward     iki_norm    tmp ite2
# 41609      none        True   472.000000  False  NaN
# 41610      none        True   180.000000  False  NaN
# 41611      none        True   259.000000  False  NaN
# 41612      none        True   250.000000  False  NaN
# 41613      none        True   275.000000  False  NaN
# 41614      none        True   127.000000  False  NaN
# 41615      none        True   403.000000  False  NaN
# 41616      none        True   360.000000  False  NaN
# 41617      none        True   340.000000  False  NaN
# 41618      none        True  1071.000000  False  NaN
# 41619      none        True     4.000000  False  NaN
# 41620      none        True     7.000000  False  NaN
# 41621      none        True     3.000000  False  NaN
# 41622      none        True     3.000000  False  NaN
# 41623      none        True     3.000000  False  NaN
# 41624      none        True     5.000000  False  NaN
# 41625      none        True     2.000000  False  NaN
# 41626  autocorr        True     1.307692  False  NaN

# %% [markdown]
# #### Two different predict backend behaviours

# %% [markdown]
# There are two predict backend behaviours. The first one will register the entire word as the key (e.g. 'guilty'), the second will only register the completed portion (e.g. 'lty'). We analyze assuming the first behaviour, but we should correct the second behaviour to be consistent. Otherwise, many mentrics are incorrecxt (e.g. the word length is currently measured by just taking the length of the key, since it

# %%
log.loc[log.ts_id == 48864].tail(5)
# Out:
#         ts_id  entry_id       key  lev_dist  \
# 135928  48864         4         u         1
# 135929  48864         4         r         1
# 135930  48864        -1                   1
# 135931  48864         5         q         1
# 135932  48864         5  uestion          8
#
#                                text_field  participant_id  len_diff     iki  \
# 135928             I hope this answer you           14665         1   176.0
# 135929            I hope this answer your           14665         1   376.0
# 135930           I hope this answer your            14665         1   300.0
# 135931          I hope this answer your q           14665         1  2871.0
# 135932  I hope this answer your question            14665         8   743.0
#
#                   text_field_prev  is_rep      ite  is_forward  iki_norm  \
# 135928      I hope this answer yo   False     none        True   176.000
# 135929     I hope this answer you   False     none        True   376.000
# 135930    I hope this answer your   False     none        True   300.000
# 135931   I hope this answer your    False     none        True  2871.000
# 135932  I hope this answer your q   False  predict        True    92.875
#
#           tmp        ite2
# 135928  False         NaN
# 135929  False         NaN
# 135930  False         NaN
# 135931  False         NaN
# 135932  False  completion

# %% [markdown]
# #### Multi-word inputs

# %% [markdown]
# Some participants exhibit a keyboard behaviour where the key contains current and previous words that were entered. We are usually able to remove this in the filtering process, but not always. Out of 9'000 post-filtered participants, it seems like 1 participant exhibits this issue.

# %%
log.loc[log.ts_id == 1507137].head(8)
# Out:
#            ts_id  entry_id                    key  lev_dist  \
# 5026801  1507137         0               Moreover        41
# 5026802  1507137         0               Moreover         0
# 5026803  1507137         1            Moreover we         3
# 5026804  1507137         1            Moreover we         0
# 5026805  1507137         2       Moreover we have         5
# 5026806  1507137         3   Moreover we have the         4
# 5026807  1507137         4   moreover we have the         1
# 5026808  1507137         4   moreover we have the         0
#
#                     text_field  participant_id  len_diff    iki  \
# 5026801               Moreover          237433        -1    NaN
# 5026802               Moreover          237433         0  115.0
# 5026803            Moreover we          237433         3   64.0
# 5026804            Moreover we          237433         0  143.0
# 5026805       Moreover we have          237433         5  180.0
# 5026806   Moreover we have the          237433         4  205.0
# 5026807   moreover we have the          237433         1   47.0
# 5026808   moreover we have the          237433         0   69.0
#
#                        text_field_prev  is_rep   ite  is_forward   iki_norm  \
# 5026801  how can we get these answers.   False  none        True        NaN
# 5026802                       Moreover   False  none        True  14.375000
# 5026803                       Moreover   False  none        True   5.818182
# 5026804                    Moreover we   False  none        True  13.000000
# 5026805                    Moreover we   False  none        True  11.250000
# 5026806               Moreover we have   False  none        True  10.250000
# 5026807           Moreover we have the   False  none        True   2.238095
# 5026808           moreover we have the   False  none        True   3.285714
#
#            tmp ite2
# 5026801  False  NaN
# 5026802  False  NaN
# 5026803  False  NaN
# 5026804  False  NaN
# 5026805  False  NaN
# 5026806  False  NaN
# 5026807  False  NaN
# 5026808  False  NaN

# %% [markdown]
# #### Consistent multicharacter inputs

# %% [markdown]
# Some participants have multicharacter inputs at the end of every word (or many words). These inputs have zero LD. This might be a side effect of having autocorrect turned on. Every time the user presses SPACE, the entire word is input, even if it was spelled correctly. This makes it hard to detect 0-LD predictions. We try to filter these out, and it seems to work quite well.

# %% [markdown]
# #### Overly broad completion condition

# %% [markdown]
#  Because the condition for completion is only that lev_dist == len_diff, then even if a letter is inserted into the middle of the word, this is considered a completion. For example, in the conjunction case: I-l-l becomes I'll. Or g-u-l-t-y becomes guilty. The former case can be argued to be a completion, but the latter is definitely not.

# %% [markdown]
# #### Overly strict completion vs. correction classificaiton

# %% [markdown]
# If somebody types 'd-e-f-o' and then completes to 'definitely', that's a completion. But currently we mark it as a correction because of the substitution between 'defo' and 'defi'.

# %% [markdown]
# #### Incorrect Levenshtein distance

# %% [markdown]
# Sometimes the Levenshtein distances appears to be incorrect. So far, this seems to happen in two cases:
# 1. A backspace is inserted. The edit distance should be 1, but the Levenshtein distance is calculated as zero.
# 2. The edit distance is completely wrong and is way too high.

# %%
log.loc[log.ts_id == 68218].iloc[27:32]
# Out:
#         ts_id  entry_id key  lev_dist             text_field  participant_id  \
# 233676  68218         2   s         1   Liverpool always has           19771
# 233677  68218        -1             2  Liverpool always has            19771
# 233678  68218         2   _         0   Liverpool always has           19771
# 233679  68218         2   _         1    Liverpool always ha           19771
# 233680  68218         2   d         1   Liverpool always had           19771
#
#         len_diff    iki        text_field_prev  is_rep   ite  is_forward  \
# 233676         1  154.0    Liverpool always ha   False  none        True
# 233677         1   82.0   Liverpool always has   False  none        True
# 233678        -1  654.0  Liverpool always has    False  none        True
# 233679        -1  133.0   Liverpool always has   False  none        True
# 233680         1  203.0    Liverpool always ha   False  none        True
#
#         iki_norm    tmp ite2
# 233676     154.0  False  NaN
# 233677      82.0  False  NaN
# 233678     654.0  False  NaN
# 233679     133.0  False  NaN
# 233680     203.0  False  NaN

# %%
log.loc[log.ts_id == 773949].head(5)
# Out:
#           ts_id  entry_id key  lev_dist text_field  participant_id  len_diff  \
# 2693245  773949         0   h         1          h          138556        -1
# 2693246  773949         0   i         1         hi          138556         1
# 2693247  773949         0   s        33        his          138556         1
# 2693248  773949        -1             1       his           138556         1
# 2693249  773949         1   m         1      his m          138556         1
#
#            iki                                    text_field_prev  is_rep  \
# 2693245    NaN  he is expected to miss six weeks of action due...   False
# 2693246  153.0                                                  h   False
# 2693247  161.0                                                 hi   False
# 2693248   92.0                                                his   False
# 2693249  535.0                                               his    False
#
#           ite  is_forward  iki_norm    tmp ite2
# 2693245  none        True       NaN  False  NaN
# 2693246  none        True     153.0  False  NaN
# 2693247  none        True     161.0  False  NaN
# 2693248  none        True      92.0  False  NaN
# 2693249  none        True     535.0  False  NaN
